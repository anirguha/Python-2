# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from pathlib import Path
import os
import shutil

# %%
zip_file = '/content/drive/MyDrive/Python/Pytorch for Deep Learning Bootcamp/data/food-101_archive.zip'

shutil.unpack_archive(zip_file, 'content/data',format="zip")

# %%
drive.flush_and_unmount()
