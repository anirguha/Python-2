# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os, shutil

shutil.copytree("/content/drive/MyDrive/Python/Helper Functions/Important PyTorch Modules/", "/content/Important PyTorch Modules")
# Out:
# '/content/Important PyTorch Modules'

# %%
drive.flush_and_unmount()

# %%
import sys
sys.path.append('/content/Important PyTorch Modules')

import data_setup

# %%
import engine
