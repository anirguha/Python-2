# %%
# !wget -O using_google_sa_in_colab.py https://github.com/anirguha/Python-2/raw/refs/heads/master/Helper%20Functions/using_google_sa_in_colab.py
# !python using_google_sa_in_colab.py
# Out:
# --2025-10-12 16:36:41--  https://github.com/anirguha/Python-2/raw/refs/heads/master/Helper%20Functions/using_google_sa_in_colab.py
# Resolving github.com (github.com)... 140.82.112.3
# Connecting to github.com (github.com)|140.82.112.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/anirguha/Python-2/refs/heads/master/Helper%20Functions/using_google_sa_in_colab.py [following]
# --2025-10-12 16:36:41--  https://raw.githubusercontent.com/anirguha/Python-2/refs/heads/master/Helper%20Functions/using_google_sa_in_colab.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 14243 (14K) [text/plain]
# Saving to: ‘using_google_sa_in_colab.py’
#
# ...

# %%
import base64

# %%
# %run using_google_sa_in_colab.py
# Out:
# ✅ Wrote and validated /content/sa.json
# JSON OK
# + apt-get -y -qq update && apt-get -y -qq install fuse rclone || true
# + rclone version
# [gdrive_sa]
# type = drive
# scope = drive
# service_account_file = /content/sa.json
# root_folder_id = 1UaoEBl_96l50YMA-cYU6Dmuuxr5Bl0Sb
#
# == rclone.conf ==
# [gdrive_sa]
# type = drive
# scope = drive
# service_account_file = /content/sa.json
# root_folder_id = 1UaoEBl_96l50YMA-cYU6Dmuuxr5Bl0Sb
# team_drive = 1UaoEBl_96l50YMA-cYU6Dmuuxr5Bl0Sb
#
#
# == rclone lsf test ==
# EXIT:0
#
# == starting mount ==
# Mounted? True  PID: 11128
# Mounted? True
# ✅ Unmounted
# phrasal-hold-327509
# Downloaded /content/sa.json via signed URL.
# Exists: True  Size: 904397 bytes
# First ~300 bytes:
# ...
