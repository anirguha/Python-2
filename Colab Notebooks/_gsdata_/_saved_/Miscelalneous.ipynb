# %%
import torch
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.lispace(-100,100,1000)
y = 1/(1+np.exp(-x))
plt.plot(x,y)
plt.show();
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-286564972.py in <cell line: 0>()
# ----> 1 x = np.lispace(-100,100,1000)
#       2 y = 1/(1+np.exp(-x))
#       3 plt.plot(x,y)
#       4 plt.show();
#
# /usr/local/lib/python3.12/dist-packages/numpy/__init__.py in __getattr__(attr)
#     408             return char.chararray
#     409
# --> 410         raise AttributeError("module {!r} has no attribute "
#     411                              "{!r}".format(__name__, attr))
#     412
#
# AttributeError: module 'numpy' has no attribute 'lispace'
