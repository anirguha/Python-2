# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

import numpy as np

# %% [markdown]
# # Generate random data

# %%
nObservations = 5
nFeatures = 10

data = np.random.randn(nObservations, nFeatures)

# %% [markdown]
# # Define a FFN model

# %%
class FFNmodel(nn.Module):
  def __init__(self):
    super().__init__()
    self.fc1 = nn.Linear(nFeatures, 32)
    self.fc2 = nn.Linear(32, 64)
    self.fc3 = nn.Linear(64, 1)

  def forward(self,x):
    print('Shape of input for layer1',x.shape)
    x = F.relu(self.fc1(x))
    print('Shape of output of layers1/ input for layer2',x.shape)
    x = F.relu(self.fc2(x))
    print('Shape of output of layers2/ input for layer3',x.shape)
    x = self.fc3(x)
    print('Shape of output of layers3',x.shape)
    return x

# %%
def createFFNmodel():
  model = FFNmodel()

  return model

# %%
model = createFFNmodel()

# print(model)
num_layers = len(list(model.named_modules())) - 1 # Subtract 1 to exclude the model itself
# print(f"Number of layers in the model: {num_layers}")


# Iterate through the children (layers) of the model
for i, layer in enumerate(model.children()):
    # Check if the layer has a 'weight' attribute (e.g., Linear layers)
    if hasattr(layer, 'weight'):
        print(f"Shape of weights in layer {i}: {layer.weight.shape}")
# Out:
# Shape of weights in layer 0: torch.Size([32, 10])
# Shape of weights in layer 1: torch.Size([64, 32])
# Shape of weights in layer 2: torch.Size([1, 64])

# %%
for i, layer in enumerate(model.children()):
    print(f"Layer {i}: {layer.weight}")
# Out:
# Layer 0: Parameter containing:
# tensor([[ 1.9492e-01, -2.9226e-01, -2.6607e-01,  3.1403e-01,  8.2372e-02,
#          -1.7077e-01,  2.0790e-02,  2.2589e-01,  2.3491e-01,  2.1570e-01],
#         [ 4.1107e-02,  1.0393e-01,  2.9854e-03,  1.0672e-01,  1.2620e-02,
#          -4.8958e-02, -3.1228e-01, -1.6840e-01, -2.5050e-01,  2.1368e-01],
#         [-1.8918e-01,  9.1118e-02, -2.5509e-01, -2.4701e-02,  3.5199e-03,
#          -1.9494e-02, -6.3512e-02,  2.7476e-01, -1.4892e-01,  1.0980e-01],
#         [-1.9609e-01, -4.4920e-02,  4.0856e-02,  1.9268e-01,  1.3596e-01,
#          -1.1703e-01, -6.2125e-02, -2.8873e-01, -3.0392e-02,  2.0585e-01],
#         [ 2.4510e-01, -1.4687e-01, -2.8015e-02,  2.0290e-01,  1.0962e-01,
#          -2.2735e-01, -2.3698e-01, -2.8117e-01,  1.8443e-01, -1.4264e-01],
#         [-2.6801e-02,  8.4459e-02,  1.1851e-01, -2.9938e-01,  2.9532e-01,
#           8.6819e-02, -9.8907e-02, -3.1066e-01,  1.8753e-01,  1.4699e-03],
#         [-2.2269e-01,  1.6708e-01,  8.4545e-02, -2.1250e-01, -6.2914e-02,
#          -7.3530e-02, -2.5272e-01,  1.1879e-01, -1.1657e-01, -8.0315e-02],
#         [-2.1550e-01, -6.9214e-02, -1.8238e-01, -1.4979e-01,  1.3728e-01,
#           5.3317e-02,  9.7033e-05, -7.4826e-02,  3.8537e-02,  8.0379e-02],
#         [-2.4376e-01, -2.4597e-01,  1.7667e-01,  8.9974e-02, -1.1330e-01,
#          -1.8117e-01, -2.7071e-01,  2.8763e-01,  9.9438e-02, -6.5557e-02],
#         [-4.5606e-02,  2.6597e-01,  2.7334e-01,  2.2143e-01,  2.6675e-01,
#           2.8644e-01,  2.1977e-01, -7.2064e-02,  3.2576e-02,  2.8345e-01],
#         [ 2.2106e-02,  2.1594e-01, -2.1058e-01,  5.7018e-02,  1.9662e-01,
#           2.8583e-01,  6.9719e-02, -1.7187e-01,  6.5187e-02, -2.1099e-01],
#         [-4.6017e-04, -2.8207e-01,  2.6856e-01,  2.0548e-01, -3.0750e-01,
#          -2.2640e-01,  2.7683e-02, -1.7424e-01, -2.1459e-01, -7.9947e-02],
#         [-7.3021e-02,  1.8956e-01, -2.0329e-01,  5.5259e-02, -1.0685e-01,
#          -1.4569e-01,  2.3479e-01, -1.6018e-01,  1.4818e-01, -1.0278e-01],
#         [-6.9995e-02, -9.8569e-02,  1.6232e-01,  1.1598e-01,  1.3753e-01,
#           1.8895e-01, -2.2383e-01,  1.8068e-01, -1.3163e-02, -2.1443e-01]],
#        requires_grad=True)
# Layer 1: Parameter containing:
# tensor([[-0.0863,  0.1487,  0.1122,  ...,  0.0738,  0.0463,  0.0380],
#         [-0.1744,  0.1629, -0.0116,  ..., -0.1659,  0.1713,  0.0588],
#         [ 0.1524,  0.0759,  0.1261,  ..., -0.0765,  0.0701, -0.1176],
#         ...,
#         [ 0.0507, -0.0115,  0.0532,  ...,  0.1747, -0.1611, -0.0976],
#         [-0.0057,  0.1074, -0.1589,  ..., -0.0827, -0.0832,  0.0821],
#         [ 0.0702, -0.0670,  0.0435,  ..., -0.1193,  0.0900,  0.0059]],
#        requires_grad=True)
# Layer 2: Parameter containing:
# tensor([[-0.1177,  0.0433, -0.0279,  0.1212, -0.0356,  0.0680,  0.0122, -0.0925,
#           0.0253,  0.0753, -0.1140, -0.1188,  0.0749, -0.0802, -0.0584, -0.0866,
#           0.0016, -0.0569, -0.0417, -0.0305, -0.0045, -0.0035, -0.0592,  0.0075,
#          -0.1019, -0.0771,  0.1003,  0.0764, -0.0764, -0.1138,  0.0235, -0.1146,
#          -0.0149,  0.0798,  0.0075,  0.0092, -0.1026, -0.1185,  0.0666,  0.0850,
#          -0.0306, -0.0378,  0.0390, -0.0032,  0.0861,  0.0669, -0.0547,  0.0406,
#           0.0636,  0.0732,  0.0120,  0.0453,  0.0661, -0.0975, -0.0331, -0.0439,
#          -0.0870,  0.0327, -0.0658,  0.0854, -0.0848, -0.1047, -0.0034,  0.0657]],
#        requires_grad=True)

# %%
model = createFFNmodel()
pred = model(torch.tensor(data).float())
# Out:
# Shape of input for layer1 torch.Size([5, 10])
# Shape of output of layers1/ input for layer2 torch.Size([5, 32])
# Shape of output of layers2/ input for layer3 torch.Size([5, 64])
# Shape of output of layers3 torch.Size([5, 1])

# %%
pd.DataFrame(pred.detach().numpy())
# Out:
#           0
# 0 -0.100992
# 1 -0.224731
# 2 -0.183670
# 3 -0.188481
# 4 -0.195387

# %%
import pandas as pd
pd.DataFrame(np.hstack((data,pred.detach().numpy())))
# Out:
#          0         1         2         3         4         5         6   \
# 0 -0.481873 -0.459125  0.304421 -0.124515  0.069573 -0.815844  1.580093
# 1  1.049184 -0.958802  0.889365  0.038393  1.758840  1.228344  1.738699
# 2 -2.099752  0.256745  0.739784 -0.099882 -0.076575 -1.712071 -0.781497
# 3 -0.951306 -0.199423  0.662827  2.123418  0.169844 -0.932263 -0.239160
# 4  0.911920 -0.585616  0.659457 -0.824523 -1.148933  0.226895 -0.235183
#
#          7         8         9         10
# 0  0.003106  1.164684 -1.844613 -0.100992
# 1 -0.375147 -0.234894  0.976182 -0.224731
# 2  0.710704  0.248783 -0.238669 -0.183670
# 3 -0.583874 -0.634938 -2.344608 -0.188481
# 4 -1.441606 -0.074159 -0.875072 -0.195387
