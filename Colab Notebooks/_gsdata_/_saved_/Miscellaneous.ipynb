# %%
import torch
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(-100,100,1000)
y = 1/(1+np.exp(-x))
plt.plot(x,y)
plt.show();

# %%
x = torch.randn(10)
print(x)
print(x.size())
# Out:
# tensor([ 0.8495, -1.7782, -0.4328, -0.7066,  1.9821, -0.7344, -0.7466, -0.2753,
#          0.2786,  0.9118])
# torch.Size([10])

# %%
torch.randn(2,3)
# Out:
# tensor([[ 0.5835,  0.0248,  0.1268],
#         [-0.7118, -0.4376, -0.0399]])

# %%
torch.randn(2,3,2).size()
# Out:
# <function Tensor.size>

# %%
x = torch.Tensor([[1,2,3],[4,5,6]])
print(x)

x = x.view(1,-1)
y = x.reshape(1,-1)
print(x, y)
# Out:
# tensor([[1., 2., 3.],
#         [4., 5., 6.]])
# tensor([[1., 2., 3., 4., 5., 6.]]) tensor([[1., 2., 3., 4., 5., 6.]])

# %%
arr = torch.Tensor([[10,20,40],[80,60, 70]])
arr
# Out:
# tensor([[10., 20., 40.],
#         [80., 60., 70.]])

# %%
arr.topk(k = 1, dim = 1)
# Out:
# torch.return_types.topk(
# values=tensor([[40.],
#         [80.]]),
# indices=tensor([[2],
#         [0]]))

# %%
x = torch.Tensor([[1,2], [3,4]])
###multiply each element by 2
x.mul_(2)
print(x)
# Out:
# tensor([[2., 4.],
#         [6., 8.]])

# %%
2 *x
# Out:
# tensor([[ 4.,  8.],
#         [12., 16.]])

# %%
x
# Out:
# tensor([[2., 4.],
#         [6., 8.]])

# %%
### To check if GPU instance is vailable in you system or not
torch.cuda.is_available()
# Out:
# False

# %%
a = torch.rand(10000,10000)
b = torch.rand(10000,10000)

import time
start = time.time()
a.matmul(b)
end = time.time()
print("{} seconds".format(end - start))
# Out:
# 16.038206338882446 seconds

# %%
a = a.cuda()
b = b.cuda()

start = time.time()
a.matmul(b)
end = time.time()
print("{} seconds".format(end - start))
# Out:
# 0.12295866012573242 seconds

# %%
from torchvision import datasets
from torchvision import transforms
trainset = datasets.MNIST(root='./data',  train=True, transform=transforms.ToTensor(),download=True)
# Out:
# 100%|██████████| 9.91M/9.91M [00:01<00:00, 5.10MB/s]
# 100%|██████████| 28.9k/28.9k [00:00<00:00, 133kB/s]
# 100%|██████████| 1.65M/1.65M [00:01<00:00, 1.27MB/s]
# 100%|██████████| 4.54k/4.54k [00:00<00:00, 7.93MB/s]

# %%
trainloader = torch.utils.data.DataLoader(trainset, batch_size=64, shuffle=True)

# %%
import matplotlib.pyplot as plt
data_iter = iter(trainloader)
images, labels = next(data_iter)

print(type(images))   ### <class 'torch.Tensor'>
print(images.shape)  ### torch.Size([64, 1, 28, 28])
print(labels.shape)  ### torch.Size([64])

plt.imshow(images[1].numpy().squeeze(), cmap='Greys_r')
plt.gca().set_title(labels[1].item())
plt.show();
# Out:
# <class 'torch.Tensor'>
# torch.Size([64, 1, 28, 28])
# torch.Size([64])
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-3739249853.py in <cell line: 0>()
#       8
#       9 plt.imshow(images[1].numpy().squeeze(), cmap='Greys_r')
# ---> 10 plt.set_title(labels[1].item())
#      11 plt.show();
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'set_title'
