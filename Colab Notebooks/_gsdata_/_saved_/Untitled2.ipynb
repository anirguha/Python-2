# %%
# !python 'cdrive/My Drive/Python/Helper Functions/Deep_Learning_Model_Helper.py'
# Out:
# python3: can't open file '/content/content/drive/My Drive/Python/Helper Functions/Deep_Learning_Model_Helper.py': [Errno 2] No such file or directory
