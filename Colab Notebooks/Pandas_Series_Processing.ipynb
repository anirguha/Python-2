# %%
import pandas as pd

# %% [markdown]
# This is a Jupyter Notebook for practicing Pandas

# %%
list_ = ["Tom","Sam","Elly","Brown"]

# %%
pd_Series1 = pd.Series(list_)

# %%
pd_Series
# Out:
# 0      Tom
# 1      Sam
# 2     Elly
# 3    Brown
# dtype: object

# %%
age = [14,14,33,29]

# %%
df = pd.DataFrame(list_,age)

# %%
pd_Series
# Out:
#         0    1     2     3
# name  Tom  Sam  Elly   NaN
# age    14   14    33  29.0

# %%
print(pd_Series)
# Out:
# name    [Tom, Sam, Elly]
# age     [14, 14, 33, 29]
# dtype: object

# %%
pd_age = pd.Series(age)

# %%
pd_age
# Out:
# 0    14
# 1    14
# 2    33
# 3    29
# dtype: int64

# %%
df = pd.DataFrame({"name":list_,"age":age})

# %%
df
# Out:
#     name  age
# 0    Tom   14
# 1    Sam   14
# 2   Elly   33
# 3  Brown   29

# %%
actor_names = ["Tom","Dick","Harry","Sam"]
actor_ages = [25,32,72.9,43]
Series1 = pd.Series(data=actor_ages,index=actor_names, name="actors")
pprint(Series1)
# Out:
# Tom      25.0
# Dick     32.0
# Harry    72.9
# Sam      43.0
# Name: actors, dtype: float64
# Tom      25.0
# Dick     32.0
# Harry    72.9
# Sam      43.0
# Name: actors, dtype: float64

# %%
print(Series1.name)
# Out:
# actors

# %%
actor_name_age = dict(zip(actor_names,actor_ages))

# %%
actor_name_age
# Out:
# {'Tom': 25, 'Dick': 32, 'Harry': 72.9, 'Sam': 43}

# %%
Series3 = pd.Series(actor_name_age)

# %%
Series3
# Out:
# Tom      25.0
# Dick     32.0
# Harry    72.9
# Sam      43.0
# dtype: float64

# %%
Series3.rename("actor_name")
# Out:
# Tom      25.0
# Dick     32.0
# Harry    72.9
# Sam      43.0
# Name: actor_name, dtype: float64

# %%
Series3.__dict__
# Out:
# {'_is_copy': None,
#  '_mgr': SingleBlockManager
#  Items: Index(['Tom', 'Dick', 'Harry', 'Sam'], dtype='object')
#  NumpyBlock: 4 dtype: float64,
#  '_item_cache': {},
#  '_attrs': {},
#  '_flags': <Flags(allows_duplicate_labels=True)>,
#  '_name': None}

# %%
Series3.name = "actors"

# %%
Series3.__dict__
# Out:
# {'_is_copy': None,
#  '_mgr': SingleBlockManager
#  Items: Index(['Tom', 'Dick', 'Harry', 'Sam'], dtype='object')
#  NumpyBlock: 4 dtype: float64,
#  '_item_cache': {},
#  '_attrs': {},
#  '_flags': <Flags(allows_duplicate_labels=True)>,
#  '_name': 'actors'}

# %%
Series3.items()

# %%
dict(Series3.items())
# Out:
# {'Tom': 25.0, 'Dick': 32.0, 'Harry': 72.9, 'Sam': 43.0}

# %%
Series4 = pd.Series({name:age for name, age in zip(actor_names,actor_ages)})

# %%
Series4
# Out:
# Tom      25.0
# Dick     32.0
# Harry    72.9
# Sam      43.0
# dtype: float64

# %%
int_series = pd.Series(range(1000))

# %%
int_series.head()
# Out:
# 0    0
# 1    1
# 2    2
# 3    3
# 4    4
# dtype: int64

# %%
int_series.tail()
# Out:
# 995    995
# 996    996
# 997    997
# 998    998
# 999    999
# dtype: int64

# %%
s = pd.Series([1,2,3,4,5],name="Numbers")

# %%
s
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# Name: Numbers, dtype: int64

# %%
s.__dict__
# Out:
# {'_is_copy': None,
#  '_mgr': SingleBlockManager
#  Items: RangeIndex(start=0, stop=5, step=1)
#  NumpyBlock: 5 dtype: int64,
#  '_item_cache': {},
#  '_attrs': {},
#  '_flags': <Flags(allows_duplicate_labels=True)>,
#  '_name': 'Numbers'}

# %%
pandas.__verson__
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-78-84c0c7d0301f> in <cell line: 0>()
# ----> 1 pandas.__verson__
#
# NameError: name 'pandas' is not defined

# %%
pd.__version__
# Out:
# '2.2.2'
