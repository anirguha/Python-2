# %%
lst1 = [1,2,3,4,5]
lst2 = ['a','b','c','d','e']
lst_comb = list(zip(lst1,lst2))
print(lst_comb)
# Out:
# [(1, 'a'), (2, 'b'), (3, 'c'), (4, 'd'), (5, 'e')]

# %%
lst_dict = dict(zip(lst1,lst2))
print(lst_dict)
# Out:
# {1: 'a', 2: 'b', 3: 'c', 4: 'd', 5: 'e'}

# %%
import pandas as pd

# %%
s = pd.Series(lst2, name='letters')
print(s)
s
# Out:
# 0    a
# 1    b
# 2    c
# 3    d
# 4    e
# Name: letters, dtype: object
# 0    a
# 1    b
# 2    c
# 3    d
# 4    e
# Name: letters, dtype: object

# %%
s2 = pd.Series(lst2, name='letters')
s2
# Out:
# 0    a
# 1    b
# 2    c
# 3    d
# 4    e
# Name: letters, dtype: object
