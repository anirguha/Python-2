# %%
def my_func(a = 1,b = 2,c = 3):
  print(f'a = {a}, b = {b}, c = {c}')

# %%
my_func(7, c=30, b = 22)
# Out:
# a = 7, b = 22, c = 30

# %%
a, b, c = 10, 20,'hello'

# %%
l = [1, 2, 3, 4, 5]
a, *b, c ,d = l

print(a)
print(b)
print(c)
print(d)
# Out:
# 1
# [2, 3]
# 4
# 5

# %%
a, *b = 'Hello'
l = [*"Hello"]
l
# Out:
# ['H', 'e', 'l', 'l', 'o']

# %%
a, *b, (c, *d) = [1, 2, 3, 'python']
a, b, c, d
# Out:
# (1, [2, 3], 'p', ['y', 't', 'h', 'o', 'n'])

# %%
l = [1, 2, 3, 4, 5, 6]

# %%
a, *b = l
a, b
# Out:
# (1, [2, 3, 4, 5, 6])

# %%
def func1(a, b, *args):
  c, *d = args
  print(c)

# %%
func1(3, 4)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-9-1930641168.py in <cell line: 0>()
# ----> 1 func1(3, 4)
#
# /tmp/ipython-input-7-2499309688.py in func1(a, b, *args)
#       1 def func1(a, b, *args):
# ----> 2   c, *d = args
#       3   print(c)
#
# ValueError: not enough values to unpack (expected at least 1, got 0)
