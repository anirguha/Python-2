# %%
from pathlib import Path

folder = Path("/content/Important PyTorch Modules")

import shutil

if folder.is_dir():
  shutil.rmtree(folder)
else:
  print(f"{folder} does not exist")
# Out:
# /content/Important PyTorch Modules does not exist

# %%
# %cd /content
# !git clone https://github.com/anirguha/Python-2.git
# Out:
# /content
# Cloning into 'Python-2'...
# remote: Enumerating objects: 1690, done.
# remote: Counting objects: 100% (94/94), done.
# remote: Compressing objects: 100% (74/74), done.
# remote: Total 1690 (delta 34), reused 51 (delta 20), pack-reused 1596 (from 6)
# Receiving objects: 100% (1690/1690), 524.72 MiB | 23.72 MiB/s, done.
# Resolving deltas: 100% (590/590), done.
# Updating files: 100% (1171/1171), done.

# %%
# !mv -u "/content/Python-2/Helper Functions/Important PyTorch Modules" .
# Out:
# mv: cannot stat '/content/Python-2/Helper Functions/Important PyTorch Modules': No such file or directory

# %%
# !rm -rf "/content/Python-2"

# %%
from pathlib import Path
import sys

folder = Path("/content/Important PyTorch Modules")

if folder not in sys.path:
    sys.path.append(folder)

# %%
# %run "/content/Important PyTorch Modules/get_data.py"
# Out:
# Did not find data/pizza_steak_sushi directory, creating one...
# ...
# Unzipping pizza, steak, sushi data...

# %%
# %cd "/content/Important PyTorch Modules"
# import train                    # safe import now
# train.main([
#     "--num_epochs", "10",
#     "--batch_size", "64",
#     "--hidden_units", "128",
#     "--learning_rate", "0.0005",
#     "--train_dir", "data/pizza_steak_sushi/train",
#     "--test_dir", "data/pizza_steak_sushi/test",
# ])

# %%
# %run "/content/Important PyTorch Modules/train.py" --num_epochs 10
# Out:
# [INFO] Training a model for 10 epochs with batch size 32 using 10 hidden units and a learning rate of 0.001
# [INFO] Training data file: data/pizza_steak_sushi/train
# [INFO] Testing data file: data/pizza_steak_sushi/test
#   0%|          | 0/10 [00:00<?, ?it/s]
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:666: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
# Epoch: 1 | train_loss: 1.0978 | train_acc: 0.3906 | test_loss: 1.0878 | test_acc: 0.5417
# Epoch: 2 | train_loss: 1.0996 | train_acc: 0.2812 | test_loss: 1.0864 | test_acc: 0.5417
# Epoch: 3 | train_loss: 1.0959 | train_acc: 0.4023 | test_loss: 1.0885 | test_acc: 0.5417
# Epoch: 4 | train_loss: 1.1037 | train_acc: 0.2812 | test_loss: 1.0849 | test_acc: 0.5417
# Epoch: 5 | train_loss: 1.0952 | train_acc: 0.4336 | test_loss: 1.0918 | test_acc: 0.2604
# ...

# %%
shutil.rmtree("/content/data")

# %%
import requests

import zipfile

url="https://github.com/anirguha/Python-2/raw/refs/heads/master/Pytorch%20for%20Deep%20Learning%20Bootcamp/data/pizza_steak_sushi.zip"

r=requests.get(url)

with open("pizza_steak_sushi.zip","wb") as f:
  f.write(r.content)

# %%
#Unzip the file contents
zip_path = "/content/pizza_steak_sushi.zip"
extract_dir = "/content/data"

with zipfile.ZipFile(zip_path,"r") as zip_ref:
  zip_ref.extractall(extract_dir)

print("Unzip Completed")
# Out:
# Unzip Completed

# %%
# Remove the zipfile
import os

os.remove(zip_path)

# %%
import os
import sys
os.chdir("/content/Important PyTorch Modules")
sys.path.append(os.getcwd())


import data_setup, engine, get_data, model_builder

# %%
import importlib, train
importlib.reload(train)
# Out:
# <module 'train' from '/content/Important PyTorch Modules/train.py'>

# %%
train.main([
    "--num_epochs", "5",
    "--batch_size", "64",
])
# Out:
# [INFO] Training a model for 5 epochs with batch size 64 using 10 hidden units and a learning rate of 0.001
# [INFO] Training data file: data/pizza_steak_sushi/train
# [INFO] Testing data file: data/pizza_steak_sushi/test
#   0%|          | 0/5 [00:00<?, ?it/s]
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:666: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
# Epoch: 1 | train_loss: 1.1008 | train_acc: 0.3023 | test_loss: 1.1147 | test_acc: 0.1953
# Epoch: 2 | train_loss: 1.0908 | train_acc: 0.3451 | test_loss: 1.0876 | test_acc: 0.1953
# Epoch: 3 | train_loss: 1.0765 | train_acc: 0.4408 | test_loss: 1.0788 | test_acc: 0.3175
# Epoch: 4 | train_loss: 1.0494 | train_acc: 0.5116 | test_loss: 1.0729 | test_acc: 0.2642
# Epoch: 5 | train_loss: 1.0242 | train_acc: 0.4622 | test_loss: 1.0706 | test_acc: 0.3253
# [INFO] Saving model to: models/tinyvgg_modified.pth

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %run train --num_epochs 5 --batch_size 32
# Out:
# [INFO] Training a model for 5 epochs with batch size 32 using 10 hidden units and a learning rate of 0.001
# [INFO] Training data file: data/pizza_steak_sushi/train
# [INFO] Testing data file: data/pizza_steak_sushi/test
#   0%|          | 0/5 [00:00<?, ?it/s]
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:666: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
# Epoch: 1 | train_loss: 1.1142 | train_acc: 0.3008 | test_loss: 1.1040 | test_acc: 0.2917
# Epoch: 2 | train_loss: 1.1049 | train_acc: 0.2812 | test_loss: 1.0789 | test_acc: 0.5417
# Epoch: 3 | train_loss: 1.0684 | train_acc: 0.4492 | test_loss: 1.1274 | test_acc: 0.2604
# Epoch: 4 | train_loss: 1.1256 | train_acc: 0.3047 | test_loss: 1.1214 | test_acc: 0.2604
# Epoch: 5 | train_loss: 1.0866 | train_acc: 0.4258 | test_loss: 1.1076 | test_acc: 0.2604
# [INFO] Saving model to: models/tinyvgg_modified.pth

# %%
import predict
importlib.reload(predict)
# Out:
# [INFO] Predicting on None
# <module 'predict' from '/content/Important PyTorch Modules/predict.py'>
