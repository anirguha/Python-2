# %%
import shutil
shutil.rmtree("/content/Important PyTorch Modules")

# %%
# %cd /content
# !git clone https://github.com/anirguha/Python-2.git
# Out:
# /content
# Cloning into 'Python-2'...
# remote: Enumerating objects: 1676, done.
# remote: Counting objects: 100% (80/80), done.
# remote: Compressing objects: 100% (67/67), done.
# remote: Total 1676 (delta 26), reused 36 (delta 13), pack-reused 1596 (from 6)
# Receiving objects: 100% (1676/1676), 524.69 MiB | 28.02 MiB/s, done.
# Resolving deltas: 100% (582/582), done.
# Updating files: 100% (1170/1170), done.

# %%
# !mv -u "/content/Python-2/Helper Functions/Important PyTorch Modules" .

# %%
# !rm -rf "/content/Python-2"

# %%
from pathlib import Path
import sys

folder = Path("/content/Important PyTorch Modules")

if folder not in sys.path:
    sys.path.append(folder)

# %%
# %run "/content/Important PyTorch Modules/get_data.py"
# Out:
# data/pizza_steak_sushi directory exists.
# Downloading pizza, steak, sushi data...
# Unzipping pizza, steak, sushi data...

# %%
# %cd "/content/Important PyTorch Modules"
# import train                    # safe import now
# train.main([
#     "--num_epochs", "10",
#     "--batch_size", "64",
#     "--hidden_units", "128",
#     "--learning_rate", "0.0005",
#     "--train_dir", "data/pizza_steak_sushi/train",
#     "--test_dir", "data/pizza_steak_sushi/test",
# ])

# %%
# %run "/content/Important PyTorch Modules/train.py" --num_epochs 10
# Out:
# [INFO] Training a model for 10 epochs with batch size 32 using 10 hidden units and a learning rate of 0.001
# [INFO] Training data file: data/pizza_steak_sushi/train
# [INFO] Testing data file: data/pizza_steak_sushi/test
#   0%|          | 0/10 [00:00<?, ?it/s]
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:666: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
# Epoch: 1 | train_loss: 1.1092 | train_acc: 0.2891 | test_loss: 1.1326 | test_acc: 0.2604
# Epoch: 2 | train_loss: 1.0887 | train_acc: 0.4648 | test_loss: 1.1334 | test_acc: 0.1979
# Epoch: 3 | train_loss: 1.0831 | train_acc: 0.4141 | test_loss: 1.1413 | test_acc: 0.1979
# Epoch: 4 | train_loss: 1.1092 | train_acc: 0.2930 | test_loss: 1.1399 | test_acc: 0.1979
# Epoch: 5 | train_loss: 1.1043 | train_acc: 0.2930 | test_loss: 1.1179 | test_acc: 0.1979
# Epoch: 6 | train_loss: 1.0801 | train_acc: 0.5156 | test_loss: 1.0978 | test_acc: 0.2708
# Epoch: 7 | train_loss: 1.0821 | train_acc: 0.4062 | test_loss: 1.0966 | test_acc: 0.2917
# Epoch: 8 | train_loss: 1.0679 | train_acc: 0.4883 | test_loss: 1.0711 | test_acc: 0.2812
# Epoch: 9 | train_loss: 1.0285 | train_acc: 0.5547 | test_loss: 1.0755 | test_acc: 0.3116
# Epoch: 10 | train_loss: 0.9986 | train_acc: 0.5000 | test_loss: 1.0376 | test_acc: 0.3523
# [INFO] Saving model to: models/05_going_modular_script_mode_tinyvgg_model.pth
