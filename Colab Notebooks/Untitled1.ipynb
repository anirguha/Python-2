# %%
try:
  import emoji
except:
  # !pip install emoji
  import emoji
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 608.4/608.4 kB 16.1 MB/s eta 0:00:00
# ...

# %%
emoji.emojize("Python is :Happy:", language="alias")
# Out:
# 'Python is :Happy:'

# %%
emoji.emojize(":onion:")
# Out:
# '🧅'

# %%
emoji.emojize(":onion:", language="alias")
# Out:
# '🧅'

# %%
# Display all emojis and their aliases from the dictionary
for emoji_alias, emoji_char in emoji.EMOJI_DATA.items():
    print(f"Alias: {emoji_alias}, Emoji: {emoji_char}")
# Out:
# Alias: 🥇, Emoji: {'en': ':1st_place_medal:', 'status': 2, 'E': 3}
# Alias: 🥈, Emoji: {'en': ':2nd_place_medal:', 'status': 2, 'E': 3}
# Alias: 🥉, Emoji: {'en': ':3rd_place_medal:', 'status': 2, 'E': 3}
# Alias: 🆎, Emoji: {'en': ':AB_button_(blood_type):', 'status': 2, 'E': 0.6, 'alias': [':ab:', ':ab_button_blood_type:']}
# Alias: 🏧, Emoji: {'en': ':ATM_sign:', 'status': 2, 'E': 0.6, 'alias': [':atm:', ':atm_sign:']}
# Alias: 🅰️, Emoji: {'en': ':A_button_(blood_type):', 'status': 2, 'E': 0.6, 'alias': [':a:', ':a_button_blood_type:'], 'variant': True}
# Alias: 🅰, Emoji: {'en': ':A_button_(blood_type):', 'status': 4, 'E': 0.6, 'alias': [':a:', ':a_button_blood_type:'], 'variant': True}
# Alias: 🇦🇫, Emoji: {'en': ':Afghanistan:', 'status': 2, 'E': 2, 'alias': [':flag_for_Afghanistan:', ':afghanistan:']}
# Alias: 🇦🇱, Emoji: {'en': ':Albania:', 'status': 2, 'E': 2, 'alias': [':flag_for_Albania:', ':albania:']}
# ...
