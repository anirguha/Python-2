# %%
# %%bash
# set -euo pipefail
#
# echo ">>> Showing which node is on PATH (and version)"
# which node || true
# node --version || true
#
# echo ">>> Installing modern Node (>=18,<21) into the current conda env"
# conda install -y -c conda-forge "nodejs>=18,<21"
#
# echo ">>> Confirming node after install"
# which node
# node --version
#
# echo ">>> Making sure Python build tooling is recent"
# pip install -U pip wheel build hatchling hatch-jupyter-builder
#
# echo ">>> Installing JupyterLab 4.4.9 from the GitHub tag (will build assets)"
# pip install --no-cache-dir "git+https://github.com/jupyterlab/jupyterlab.git@v4.4.9"
#
# echo ">>> Verifying"
# python - <<'PY'
# import jupyterlab
# print("✅ JupyterLab version:", jupyterlab.__version__)
# PY
# Out:
# >>> Showing which node is on PATH (and version)
# /opt/anaconda3/envs/DL_env/bin/node
# v20.17.0
# >>> Installing modern Node (>=18,<21) into the current conda env
# Channels:
#  - conda-forge
#  - defaults
# Platform: osx-64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# # All requested packages already installed.
#
# >>> Confirming node after install
# /opt/anaconda3/envs/DL_env/bin/node
# v20.17.0
# >>> Making sure Python build tooling is recent
# Requirement already satisfied: pip in /opt/anaconda3/envs/DL_env/lib/python3.11/site-packages (25.2)
# Requirement already satisfied: wheel in /opt/anaconda3/envs/DL_env/lib/python3.11/site-packages (0.45.1)
# Requirement already satisfied: build in /opt/anaconda3/envs/DL_env/lib/python3.11/site-packages (1.3.0)
# Requirement already satisfied: hatchling in /opt/anaconda3/envs/DL_env/lib/python3.11/site-packages (1.27.0)
# Requirement already satisfied: hatch-jupyter-builder in /opt/anaconda3/envs/DL_env/lib/python3.11/site-packages (0.9.1)
# Requirement already satisfied: packaging>=19.1 in /opt/anaconda3/envs/DL_env/lib/python3.11/site-packages (from build) (25.0)
# Requirement already satisfied: pyproject_hooks in /opt/anaconda3/envs/DL_env/lib/python3.11/site-packages (from build) (1.2.0)
# Requirement already satisfied: pathspec>=0.10.1 in /opt/anaconda3/envs/DL_env/lib/python3.11/site-packages (from hatchling) (0.12.1)
# Requirement already satisfied: pluggy>=1.0.0 in /opt/anaconda3/envs/DL_env/lib/python3.11/site-packages (from hatchling) (1.6.0)
# Requirement already satisfied: trove-classifiers in /opt/anaconda3/envs/DL_env/lib/python3.11/site-packages (from hatchling) (2025.9.11.17)
# >>> Installing JupyterLab 4.4.9 from the GitHub tag (will build assets)
# Collecting git+https://github.com/jupyterlab/jupyterlab.git@v4.4.9
#   Cloning https://github.com/jupyterlab/jupyterlab.git (to revision v4.4.9) to /private/var/folders/mq/h979j9sj6f38h5m8d5wmkysw0000gp/T/pip-req-build-w3o9sye9
#   Running command git clone --filter=blob:none --quiet https://github.com/jupyterlab/jupyterlab.git /private/var/folders/mq/h979j9sj6f38h5m8d5wmkysw0000gp/T/pip-req-build-w3o9sye9
#   Running command git checkout -q d13e4a90c2a39d5356fe2c81727163172276d525
#   Resolved https://github.com/jupyterlab/jupyterlab.git to commit d13e4a90c2a39d5356fe2c81727163172276d525
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Installing backend dependencies: started
#   Installing backend dependencies: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: async-lru>=1.0.0 in /opt/anaconda3/envs/DL_env/lib/python3.11/site-packages (from jupyterlab==4.4.9) (2.0.4)
# Requirement already satisfied: httpx<1,>=0.25.0 in /opt/anaconda3/envs/DL_env/lib/python3.11/site-packages (from jupyterlab==4.4.9) (0.28.1)
# Requirement already satisfied: ipykernel!=6.30.0,>=6.5.0 in /opt/anaconda3/envs/DL_env/lib/python3.11/site-packages (from jupyterlab==4.4.9) (6.29.5)
# Requirement already satisfied: jinja2>=3.0.3 in /opt/anaconda3/envs/DL_env/lib/python3.11/site-packages (from jupyterlab==4.4.9) (3.1.6)
# Requirement already satisfied: jupyter-core in /opt/anaconda3/envs/DL_env/lib/python3.11/site-packages (from jupyterlab==4.4.9) (5.8.1)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /opt/anaconda3/envs/DL_env/lib/python3.11/site-packages (from jupyterlab==4.4.9) (2.2.5)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /opt/anaconda3/envs/DL_env/lib/python3.11/site-packages (from jupyterlab==4.4.9) (2.16.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in /opt/anaconda3/envs/DL_env/lib/python3.11/site-packages (from jupyterlab==4.4.9) (2.27.3)
# Requirement already satisfied: notebook-shim>=0.2 in /opt/anaconda3/envs/DL_env/lib/python3.11/site-packages (from jupyterlab==4.4.9) (0.2.4)
# Requirement already satisfied: packaging in /opt/anaconda3/envs/DL_env/lib/python3.11/site-packages (from jupyterlab==4.4.9) (25.0)
# Requirement already satisfied: setuptools>=41.1.0 in /opt/anaconda3/envs/DL_env/lib/python3.11/site-packages (from jupyterlab==4.4.9) (78.1.1)
# Requirement already satisfied: tornado>=6.2.0 in /opt/anaconda3/envs/DL_env/lib/python3.11/site-packages (from jupyterlab==4.4.9) (6.5.1)
# Requirement already satisfied: traitlets in /opt/anaconda3/envs/DL_env/lib/python3.11/site-packages (from jupyterlab==4.4.9) (5.14.3)
# Requirement already satisfied: anyio in /opt/anaconda3/envs/DL_env/lib/python3.11/site-packages (from httpx<1,>=0.25.0->jupyterlab==4.4.9) (4.7.0)
# Requirement already satisfied: certifi in /opt/anaconda3/envs/DL_env/lib/python3.11/site-packages (from httpx<1,>=0.25.0->jupyterlab==4.4.9) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in /opt/anaconda3/envs/DL_env/lib/python3.11/site-packages (from httpx<1,>=0.25.0->jupyterlab==4.4.9) (1.0.9)
# Requirement already satisfied: idna in /opt/anaconda3/envs/DL_env/lib/python3.11/site-packages (from httpx<1,>=0.25.0->jupyterlab==4.4.9) (3.7)
# Requirement already satisfied: h11>=0.16 in /opt/anaconda3/envs/DL_env/lib/python3.11/site-packages (from httpcore==1.*->httpx<1,>=0.25.0->jupyterlab==4.4.9) (0.16.0)
# Requirement already satisfied: argon2-cffi>=21.1 in /opt/anaconda3/envs/DL_env/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab==4.4.9) (21.3.0)
# Requirement already satisfied: jupyter-client>=7.4.4 in /opt/anaconda3/envs/DL_env/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab==4.4.9) (8.6.3)
# Requirement already satisfied: jupyter-events>=0.11.0 in /opt/anaconda3/envs/DL_env/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab==4.4.9) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /opt/anaconda3/envs/DL_env/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab==4.4.9) (0.5.3)
# Requirement already satisfied: nbconvert>=6.4.4 in /opt/anaconda3/envs/DL_env/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab==4.4.9) (7.16.6)
# Requirement already satisfied: nbformat>=5.3.0 in /opt/anaconda3/envs/DL_env/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab==4.4.9) (5.10.4)
# Requirement already satisfied: overrides>=5.0 in /opt/anaconda3/envs/DL_env/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab==4.4.9) (7.4.0)
# Requirement already satisfied: prometheus-client>=0.9 in /opt/anaconda3/envs/DL_env/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab==4.4.9) (0.21.1)
# Requirement already satisfied: pyzmq>=24 in /opt/anaconda3/envs/DL_env/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab==4.4.9) (26.2.0)
# Requirement already satisfied: send2trash>=1.8.2 in /opt/anaconda3/envs/DL_env/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab==4.4.9) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in /opt/anaconda3/envs/DL_env/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab==4.4.9) (0.17.1)
# Requirement already satisfied: websocket-client>=1.7 in /opt/anaconda3/envs/DL_env/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab==4.4.9) (1.8.0)
# Requirement already satisfied: babel>=2.10 in /opt/anaconda3/envs/DL_env/lib/python3.11/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab==4.4.9) (2.16.0)
# Requirement already satisfied: json5>=0.9.0 in /opt/anaconda3/envs/DL_env/lib/python3.11/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab==4.4.9) (0.9.25)
# Requirement already satisfied: jsonschema>=4.18.0 in /opt/anaconda3/envs/DL_env/lib/python3.11/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab==4.4.9) (4.25.0)
# Requirement already satisfied: requests>=2.31 in /opt/anaconda3/envs/DL_env/lib/python3.11/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab==4.4.9) (2.32.4)
# Requirement already satisfied: sniffio>=1.1 in /opt/anaconda3/envs/DL_env/lib/python3.11/site-packages (from anyio->httpx<1,>=0.25.0->jupyterlab==4.4.9) (1.3.0)
# Requirement already satisfied: typing_extensions>=4.5 in /opt/anaconda3/envs/DL_env/lib/python3.11/site-packages (from anyio->httpx<1,>=0.25.0->jupyterlab==4.4.9) (4.12.2)
# Requirement already satisfied: argon2-cffi-bindings in /opt/anaconda3/envs/DL_env/lib/python3.11/site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab==4.4.9) (21.2.0)
# Requirement already satisfied: appnope in /opt/anaconda3/envs/DL_env/lib/python3.11/site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab==4.4.9) (0.1.4)
# Requirement already satisfied: comm>=0.1.1 in /opt/anaconda3/envs/DL_env/lib/python3.11/site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab==4.4.9) (0.2.1)
# Requirement already satisfied: debugpy>=1.6.5 in /opt/anaconda3/envs/DL_env/lib/python3.11/site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab==4.4.9) (1.8.11)
# Requirement already satisfied: ipython>=7.23.1 in /opt/anaconda3/envs/DL_env/lib/python3.11/site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab==4.4.9) (9.1.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in /opt/anaconda3/envs/DL_env/lib/python3.11/site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab==4.4.9) (0.1.6)
# Requirement already satisfied: nest-asyncio in /opt/anaconda3/envs/DL_env/lib/python3.11/site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab==4.4.9) (1.6.0)
# Requirement already satisfied: psutil in /opt/anaconda3/envs/DL_env/lib/python3.11/site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab==4.4.9) (5.9.0)
# Requirement already satisfied: decorator in /opt/anaconda3/envs/DL_env/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab==4.4.9) (5.1.1)
# Requirement already satisfied: ipython-pygments-lexers in /opt/anaconda3/envs/DL_env/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab==4.4.9) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in /opt/anaconda3/envs/DL_env/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab==4.4.9) (0.19.2)
# Requirement already satisfied: pexpect>4.3 in /opt/anaconda3/envs/DL_env/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab==4.4.9) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /opt/anaconda3/envs/DL_env/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab==4.4.9) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in /opt/anaconda3/envs/DL_env/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab==4.4.9) (2.19.1)
# Requirement already satisfied: stack_data in /opt/anaconda3/envs/DL_env/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab==4.4.9) (0.2.0)
# Requirement already satisfied: wcwidth in /opt/anaconda3/envs/DL_env/lib/python3.11/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab==4.4.9) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /opt/anaconda3/envs/DL_env/lib/python3.11/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab==4.4.9) (0.8.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/envs/DL_env/lib/python3.11/site-packages (from jinja2>=3.0.3->jupyterlab==4.4.9) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in /opt/anaconda3/envs/DL_env/lib/python3.11/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab==4.4.9) (24.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/anaconda3/envs/DL_env/lib/python3.11/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab==4.4.9) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/anaconda3/envs/DL_env/lib/python3.11/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab==4.4.9) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/anaconda3/envs/DL_env/lib/python3.11/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab==4.4.9) (0.22.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/envs/DL_env/lib/python3.11/site-packages (from jupyter-client>=7.4.4->jupyter-server<3,>=2.4.0->jupyterlab==4.4.9) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5 in /opt/anaconda3/envs/DL_env/lib/python3.11/site-packages (from jupyter-core->jupyterlab==4.4.9) (4.3.7)
# Requirement already satisfied: python-json-logger>=2.0.4 in /opt/anaconda3/envs/DL_env/lib/python3.11/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab==4.4.9) (3.2.1)
# Requirement already satisfied: pyyaml>=5.3 in /opt/anaconda3/envs/DL_env/lib/python3.11/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab==4.4.9) (6.0.2)
# Requirement already satisfied: rfc3339-validator in /opt/anaconda3/envs/DL_env/lib/python3.11/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab==4.4.9) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /opt/anaconda3/envs/DL_env/lib/python3.11/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab==4.4.9) (0.1.1)
# Requirement already satisfied: fqdn in /opt/anaconda3/envs/DL_env/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab==4.4.9) (1.5.1)
# Requirement already satisfied: isoduration in /opt/anaconda3/envs/DL_env/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab==4.4.9) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /opt/anaconda3/envs/DL_env/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab==4.4.9) (3.0.0)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in /opt/anaconda3/envs/DL_env/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab==4.4.9) (1.1.0)
# Requirement already satisfied: uri-template in /opt/anaconda3/envs/DL_env/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab==4.4.9) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /opt/anaconda3/envs/DL_env/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab==4.4.9) (24.11.1)
# Requirement already satisfied: beautifulsoup4 in /opt/anaconda3/envs/DL_env/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab==4.4.9) (4.13.4)
# Requirement already satisfied: bleach!=5.0.0 in /opt/anaconda3/envs/DL_env/lib/python3.11/site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab==4.4.9) (6.2.0)
# Requirement already satisfied: defusedxml in /opt/anaconda3/envs/DL_env/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab==4.4.9) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /opt/anaconda3/envs/DL_env/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab==4.4.9) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /opt/anaconda3/envs/DL_env/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab==4.4.9) (3.1.2)
# Requirement already satisfied: nbclient>=0.5.0 in /opt/anaconda3/envs/DL_env/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab==4.4.9) (0.10.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /opt/anaconda3/envs/DL_env/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab==4.4.9) (1.5.0)
# Requirement already satisfied: webencodings in /opt/anaconda3/envs/DL_env/lib/python3.11/site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab==4.4.9) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /opt/anaconda3/envs/DL_env/lib/python3.11/site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab==4.4.9) (1.4.0)
# Requirement already satisfied: fastjsonschema>=2.15 in /opt/anaconda3/envs/DL_env/lib/python3.11/site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->jupyterlab==4.4.9) (2.20.0)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/anaconda3/envs/DL_env/lib/python3.11/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab==4.4.9) (0.7.0)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/DL_env/lib/python3.11/site-packages (from python-dateutil>=2.8.2->jupyter-client>=7.4.4->jupyter-server<3,>=2.4.0->jupyterlab==4.4.9) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/anaconda3/envs/DL_env/lib/python3.11/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->jupyterlab==4.4.9) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/envs/DL_env/lib/python3.11/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->jupyterlab==4.4.9) (2.5.0)
# Requirement already satisfied: lark>=1.2.2 in /opt/anaconda3/envs/DL_env/lib/python3.11/site-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab==4.4.9) (1.3.0)
# Requirement already satisfied: cffi>=1.0.1 in /opt/anaconda3/envs/DL_env/lib/python3.11/site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab==4.4.9) (1.17.1)
# Requirement already satisfied: pycparser in /opt/anaconda3/envs/DL_env/lib/python3.11/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab==4.4.9) (2.21)
# Requirement already satisfied: soupsieve>1.2 in /opt/anaconda3/envs/DL_env/lib/python3.11/site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab==4.4.9) (2.5)
# Requirement already satisfied: arrow>=0.15.0 in /opt/anaconda3/envs/DL_env/lib/python3.11/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab==4.4.9) (1.4.0)
# Requirement already satisfied: tzdata in /opt/anaconda3/envs/DL_env/lib/python3.11/site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab==4.4.9) (2025.2)
# Requirement already satisfied: executing in /opt/anaconda3/envs/DL_env/lib/python3.11/site-packages (from stack_data->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab==4.4.9) (0.8.3)
# Requirement already satisfied: asttokens in /opt/anaconda3/envs/DL_env/lib/python3.11/site-packages (from stack_data->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab==4.4.9) (3.0.0)
# Requirement already satisfied: pure-eval in /opt/anaconda3/envs/DL_env/lib/python3.11/site-packages (from stack_data->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab==4.4.9) (0.2.2)
# >>> Verifying
# ✅ JupyterLab version: 4.4.9
