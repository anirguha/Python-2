# %%
# %%bash
# set -euo pipefail
#
# echo ">>> Showing which node is on PATH (and version)"
# which node || true
# node --version || true
#
# echo ">>> Installing modern Node (>=18,<21) into the current conda env"
# conda install -y -c conda-forge "nodejs>=18,<21"
#
# echo ">>> Confirming node after install"
# which node
# node --version
#
# echo ">>> Making sure Python build tooling is recent"
# pip install -U pip wheel build hatchling hatch-jupyter-builder
#
# echo ">>> Installing JupyterLab 4.5.3 from the GitHub tag (will build assets)"
# pip install --no-cache-dir "git+https://github.com/jupyterlab/jupyterlab.git@v4.5.3"
#
# echo ">>> Verifying"
# python - <<'PY'
# import jupyterlab
# print("✅ JupyterLab version:", jupyterlab.__version__)
# PY
# Out:
# >>> Showing which node is on PATH (and version)
# /opt/anaconda3/envs/DL_env/bin/node
# v20.17.0
# >>> Installing modern Node (>=18,<21) into the current conda env
# Retrieving notices: done
# Channels:
#  - conda-forge
#  - defaults
# Platform: osx-64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/anaconda3/envs/DL_env
#
#   added / updated specs:
#     - nodejs[version='>=18,<21']
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2026.1.4   |       hbd8a1cb_0         143 KB  conda-forge
#     certifi-2026.1.4           |     pyhd8ed1ab_0         147 KB  conda-forge
#     openssl-3.6.1              |       hb6871ef_1         2.6 MB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         2.9 MB
#
# The following packages will be UPDATED:
#
#   ca-certificates                     2025.11.12-hbd8a1cb_0 --> 2026.1.4-hbd8a1cb_0
#   certifi                           2025.11.12-pyhd8ed1ab_0 --> 2026.1.4-pyhd8ed1ab_0
#   openssl                                  3.6.0-h230baf5_0 --> 3.6.1-hb6871ef_1
#
#
#
# openssl-3.6.1        | 2.6 MB    |            |   0%
# certifi-2026.1.4     | 147 KB    |            |   0%
#
# ca-certificates-2026 | 143 KB    |            |   0%
#
# openssl-3.6.1        | 2.6 MB    |            |   1%
# certifi-2026.1.4     | 147 KB    | #          |  11%
#
# ca-certificates-2026 | 143 KB    | ########## | 100%
#
# ca-certificates-2026 | 143 KB    | ########## | 100%
# certifi-2026.1.4     | 147 KB    | ########## | 100%
#
#
#
#                                                       done
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# >>> Confirming node after install
# /opt/anaconda3/envs/DL_env/bin/node
# v20.17.0
# >>> Making sure Python build tooling is recent
# Requirement already satisfied: pip in /opt/anaconda3/envs/DL_env/lib/python3.11/site-packages (25.3)
# Requirement already satisfied: wheel in /opt/anaconda3/envs/DL_env/lib/python3.11/site-packages (0.45.1)
# Collecting wheel
#   Downloading wheel-0.46.3-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: build in /opt/anaconda3/envs/DL_env/lib/python3.11/site-packages (1.3.0)
# Collecting build
#   Downloading build-1.4.0-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: hatchling in /opt/anaconda3/envs/DL_env/lib/python3.11/site-packages (1.28.0)
# Requirement already satisfied: hatch-jupyter-builder in /opt/anaconda3/envs/DL_env/lib/python3.11/site-packages (0.9.1)
# Requirement already satisfied: packaging>=24.0 in /opt/anaconda3/envs/DL_env/lib/python3.11/site-packages (from wheel) (25.0)
# Requirement already satisfied: pyproject_hooks in /opt/anaconda3/envs/DL_env/lib/python3.11/site-packages (from build) (1.2.0)
# Requirement already satisfied: pathspec>=0.10.1 in /opt/anaconda3/envs/DL_env/lib/python3.11/site-packages (from hatchling) (0.12.1)
# Requirement already satisfied: pluggy>=1.0.0 in /opt/anaconda3/envs/DL_env/lib/python3.11/site-packages (from hatchling) (1.6.0)
# Requirement already satisfied: trove-classifiers in /opt/anaconda3/envs/DL_env/lib/python3.11/site-packages (from hatchling) (2025.9.11.17)
# Downloading wheel-0.46.3-py3-none-any.whl (30 kB)
# Downloading build-1.4.0-py3-none-any.whl (24 kB)
# Installing collected packages: wheel, build
#   Attempting uninstall: wheel
#     Found existing installation: wheel 0.45.1
#     Uninstalling wheel-0.45.1:
#       Successfully uninstalled wheel-0.45.1
#   Attempting uninstall: build
#     Found existing installation: build 1.3.0
#     Uninstalling build-1.3.0:
#       Successfully uninstalled build-1.3.0
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [build]
# Successfully installed build-1.4.0 wheel-0.46.3
# >>> Installing JupyterLab 4.5.3 from the GitHub tag (will build assets)
# Collecting git+https://github.com/jupyterlab/jupyterlab.git@v4.5.3
#   Cloning https://github.com/jupyterlab/jupyterlab.git (to revision v4.5.3) to /private/var/folders/mq/h979j9sj6f38h5m8d5wmkysw0000gp/T/pip-req-build-j74pfpy0
#   Running command git clone --filter=blob:none --quiet https://github.com/jupyterlab/jupyterlab.git /private/var/folders/mq/h979j9sj6f38h5m8d5wmkysw0000gp/T/pip-req-build-j74pfpy0
#   Running command git checkout -q 24fc062e1cae20e6189359cf4a682c757bda8d5f
#   Resolved https://github.com/jupyterlab/jupyterlab.git to commit 24fc062e1cae20e6189359cf4a682c757bda8d5f
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Installing backend dependencies: started
#   Installing backend dependencies: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
