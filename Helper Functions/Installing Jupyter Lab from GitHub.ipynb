# %%
# %%bash
# set -euo pipefail
#
# echo ">>> Showing which node is on PATH (and version)"
# which node || true
# node --version || true
#
# echo ">>> Installing modern Node (>=18,<21) into the current conda env"
# conda install -y -c conda-forge "nodejs>=18,<21"
#
# echo ">>> Confirming node after install"
# which node
# node --version
#
# echo ">>> Making sure Python build tooling is recent"
# pip install -U pip wheel build hatchling hatch-jupyter-builder
#
# echo ">>> Installing JupyterLab 4.5.6 from the GitHub tag (will build assets)"
# pip install --no-cache-dir "git+https://github.com/jupyterlab/jupyterlab.git@v4.5.6"
#
# echo ">>> Verifying"
# python - <<'PY'
# import jupyterlab
# print("✅ JupyterLab version:", jupyterlab.__version__)
# PY
# Out:
# >>> Showing which node is on PATH (and version)
# /opt/anaconda3/envs/jupyterlab-debugger/bin/node
# v10.13.0
# >>> Installing modern Node (>=18,<21) into the current conda env
# Retrieving notices: done
# Channels:
#  - conda-forge
#  - defaults
# Platform: osx-64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/anaconda3/envs/jupyterlab-debugger
#
#   added / updated specs:
#     - nodejs[version='>=18,<21']
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2026.2.25  |       hbd8a1cb_0         144 KB  conda-forge
#     certifi-2026.2.25          |     pyhd8ed1ab_0         148 KB  conda-forge
#     libuv-1.51.0               |       h58003a5_1         413 KB  conda-forge
#     nodejs-20.19.6             |       h69cdba9_0        11.3 MB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        11.9 MB
#
# The following NEW packages will be INSTALLED:
#
#   libuv              conda-forge/osx-64::libuv-1.51.0-h58003a5_1
#
# The following packages will be UPDATED:
#
#   ca-certificates                       2025.8.3-hbd8a1cb_0 --> 2026.2.25-hbd8a1cb_0
#   certifi            pkgs/main/osx-64::certifi-2025.8.3-py~ --> conda-forge/noarch::certifi-2026.2.25-pyhd8ed1ab_0
#   nodejs               pkgs/main::nodejs-10.13.0-h0a44026_0 --> conda-forge::nodejs-20.19.6-h69cdba9_0
#   openssl                                  3.5.2-h6e31bce_0 --> 3.6.1-hb6871ef_1
#
#
#
# nodejs-20.19.6       | 11.3 MB   |                                      |   0%
# libuv-1.51.0         | 413 KB    |                                      |   0%
#
# certifi-2026.2.25    | 148 KB    |                                      |   0%
#
#
# ca-certificates-2026 | 144 KB    |                                      |   0%
#
# certifi-2026.2.25    | 148 KB    | ###8                                 |  11%
#
#
# ca-certificates-2026 | 144 KB    | ####                                 |  11%
# libuv-1.51.0         | 413 KB    | #3                                   |   4%
#
# certifi-2026.2.25    | 148 KB    | #################################### | 100%
#
# certifi-2026.2.25    | 148 KB    | #################################### | 100%
#
#
# ca-certificates-2026 | 144 KB    | #################################### | 100%
#
#
# ca-certificates-2026 | 144 KB    | #################################### | 100%
# libuv-1.51.0         | 413 KB    | ################7                    |  47%
# libuv-1.51.0         | 413 KB    | #################################### | 100%
#
#
#
#
#
#
#                                                                                 done
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# >>> Confirming node after install
# /opt/anaconda3/envs/jupyterlab-debugger/bin/node
# v20.19.6
# >>> Making sure Python build tooling is recent
# Requirement already satisfied: pip in /opt/anaconda3/envs/jupyterlab-debugger/lib/python3.13/site-packages (25.1)
# Collecting pip
#   Downloading pip-26.0.1-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: wheel in /opt/anaconda3/envs/jupyterlab-debugger/lib/python3.13/site-packages (0.45.1)
# Collecting wheel
#   Using cached wheel-0.46.3-py3-none-any.whl.metadata (2.4 kB)
# Collecting build
#   Using cached build-1.4.0-py3-none-any.whl.metadata (5.8 kB)
# Collecting hatchling
#   Downloading hatchling-1.29.0-py3-none-any.whl.metadata (3.8 kB)
# Collecting hatch-jupyter-builder
#   Using cached hatch_jupyter_builder-0.9.1-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: packaging>=24.0 in /opt/anaconda3/envs/jupyterlab-debugger/lib/python3.13/site-packages (from wheel) (24.2)
# Collecting pyproject_hooks (from build)
#   Using cached pyproject_hooks-1.2.0-py3-none-any.whl.metadata (1.3 kB)
# Collecting pathspec>=0.10.1 (from hatchling)
#   Using cached pathspec-1.0.4-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: pluggy>=1.0.0 in /opt/anaconda3/envs/jupyterlab-debugger/lib/python3.13/site-packages (from hatchling) (1.5.0)
# Collecting trove-classifiers (from hatchling)
#   Using cached trove_classifiers-2026.1.14.14-py3-none-any.whl.metadata (2.4 kB)
# Downloading pip-26.0.1-py3-none-any.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 17.3 MB/s eta 0:00:00
# Using cached wheel-0.46.3-py3-none-any.whl (30 kB)
# Using cached build-1.4.0-py3-none-any.whl (24 kB)
# Downloading hatchling-1.29.0-py3-none-any.whl (76 kB)
# Using cached hatch_jupyter_builder-0.9.1-py3-none-any.whl (18 kB)
# Using cached pathspec-1.0.4-py3-none-any.whl (55 kB)
# Using cached pyproject_hooks-1.2.0-py3-none-any.whl (10 kB)
# Using cached trove_classifiers-2026.1.14.14-py3-none-any.whl (14 kB)
# Installing collected packages: trove-classifiers, wheel, pyproject_hooks, pip, pathspec, hatchling, build, hatch-jupyter-builder
#   Attempting uninstall: wheel
#     Found existing installation: wheel 0.45.1
#     Uninstalling wheel-0.45.1:
#       Successfully uninstalled wheel-0.45.1
#   Attempting uninstall: pip
#     Found existing installation: pip 25.1
#     Uninstalling pip-25.1:
#       Successfully uninstalled pip-25.1
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8/8 [hatch-jupyter-builder]hling]
# Successfully installed build-1.4.0 hatch-jupyter-builder-0.9.1 hatchling-1.29.0 pathspec-1.0.4 pip-26.0.1 pyproject_hooks-1.2.0 trove-classifiers-2026.1.14.14 wheel-0.46.3
# >>> Installing JupyterLab 4.5.6 from the GitHub tag (will build assets)
# Collecting git+https://github.com/jupyterlab/jupyterlab.git@v4.5.6
#   Cloning https://github.com/jupyterlab/jupyterlab.git (to revision v4.5.6) to /private/var/folders/mq/h979j9sj6f38h5m8d5wmkysw0000gp/T/pip-req-build-2cydah3k
#   Running command git clone --filter=blob:none --quiet https://github.com/jupyterlab/jupyterlab.git /private/var/folders/mq/h979j9sj6f38h5m8d5wmkysw0000gp/T/pip-req-build-2cydah3k
