# %%
set1 = {1,2,3,4,5}
set2 = {3,4,5}
set1 - set2
# Out:
# {1, 2}

# %%
set1 & set2
# Out:
# {3, 4, 5}

# %%
set1.intersection(set2)
# Out:
# {3, 4, 5}

# %%
set1 | set2
# Out:
# {1, 2, 3, 4, 5}

# %%
set1.union(set2)
# Out:
# {1, 2, 3, 4, 5}

# %%
set1.add('a')

# %%
set1
# Out:
# {1, 2, 3, 4, 5, 'a'}
