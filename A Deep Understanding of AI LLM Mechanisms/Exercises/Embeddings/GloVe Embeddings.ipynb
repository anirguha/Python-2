# %%
try:
    import gensim.downloader as api
except:
    # !conda install gensim
    import gensim.downloader as api
finally:
    glove = api.load("glove-wiki-gigaword-50")
