# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
songs_data = pd.read_csv('/Users/AnirbanGuha/Library/CloudStorage/OneDrive-Personal/Udemy Courses/Data Science - data Prep and EDA with Python/Data+Science+in+Python+-+Data+Prep+%26+EDA/Data/spotify_songs.csv')

# %%
sns.pairplot(songs_data);

# %%
sns.histplot(songs_data.tempo)
# Out:
# <Axes: xlabel='tempo', ylabel='Count'>

# %%
songs_data.tempo.value_counts().sort_values(ascending=False)
# Out:
# tempo
# 77.169     1
# 93.394     1
# 159.847    1
# 140.124    1
# 91.030     1
#           ..
# 105.076    1
# 135.702    1
# 180.043    1
# 94.968     1
# 126.684    1
# Name: count, Length: 100, dtype: int64

# %%
songs_data.corr(numeric_only=True)
# Out:
#                energy       key      mode   valence     tempo  duration_ms
# energy       1.000000 -0.136345 -0.117555  0.382434  0.062272     0.073017
# key         -0.136345  1.000000 -0.141568 -0.032622  0.003737     0.046144
# mode        -0.117555 -0.141568  1.000000 -0.210599 -0.011911     0.055411
# valence      0.382434 -0.032622 -0.210599  1.000000 -0.148423    -0.131901
# tempo        0.062272  0.003737 -0.011911 -0.148423  1.000000     0.005493
# duration_ms  0.073017  0.046144  0.055411 -0.131901  0.005493     1.000000

# %%
sns.scatterplot(songs_data, x='energy',y='valence');

# %%
sns.histplot(songs_data.key);
# Out:
# <Axes: xlabel='key', ylabel='Count'>

# %%
songs_data.key.value_counts().sort_index()
# Out:
# key
# 0     10
# 1     15
# 2      7
# 3      4
# 4      5
# 5     10
# 6      7
# 7      6
# 8     11
# 9     10
# 10     5
# 11    10
# Name: count, dtype: int64
