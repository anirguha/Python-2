# %%
import pandas as pd
import numpy as np
import openpyxl

# %% [markdown]
# ### Creating and Manipulating Dataframes

# %%
df2 = pd.DataFrame(
    {
        "A": 1.0,
        "B": pd.Timestamp("20130102"),
        "C": pd.Series(1, index=list(range(4)), dtype="float32"),
        "D": np.array([3] * 4, dtype="int32"),
        "E": pd.Categorical(["test", "train", "test", "train"]),
        "F": "foo",
    }
)

# %%
df2
# Out:
#      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-02  1.0  3  train  foo
# 2  1.0 2013-01-02  1.0  3   test  foo
# 3  1.0 2013-01-02  1.0  3  train  foo

# %%
df2.dtypes
# Out:
# A          float64
# B    datetime64[s]
# C          float32
# D            int32
# E         category
# F           object
# dtype: object

# %%
dates = pd.date_range("20130101", periods=6)

# %%
dates
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df = pd.DataFrame(np.random.randn(6, 4), index=dates, columns=list("ABCD"))

# %%
df
# Out:
#                    A         B         C         D
# 2013-01-01  1.020579  0.681374  1.517496 -0.568167
# 2013-01-02  1.931734  0.306294  0.774480  0.574765
# 2013-01-03  1.371006  0.432753 -0.197505  0.499230
# 2013-01-04  0.096502 -1.550923  0.109702  0.960045
# 2013-01-05 -0.711432  0.830442  0.417824 -0.131395
# 2013-01-06 -0.365043 -0.631765  0.750336  2.422611

# %%
df.index
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df.columns
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %%
df.to_numpy()
# Out:
# array([[ 1.02057948,  0.68137404,  1.51749601, -0.56816736],
#        [ 1.9317342 ,  0.30629395,  0.77447959,  0.57476536],
#        [ 1.37100557,  0.43275328, -0.19750514,  0.49922963],
#        [ 0.09650153, -1.55092313,  0.10970222,  0.96004549],
#        [-0.71143155,  0.8304425 ,  0.41782402, -0.13139465],
#        [-0.36504292, -0.63176467,  0.7503356 ,  2.42261067]])

# %%
df.dtypes
# Out:
# A    float64
# B    float64
# C    float64
# D    float64
# dtype: object

# %%
df2.dtypes
# Out:
# A          float64
# B    datetime64[s]
# C          float32
# D            int32
# E         category
# F           object
# dtype: object

# %%
df.describe()
# Out:
#               A         B         C         D
# count  6.000000  6.000000  6.000000  6.000000
# mean   0.557224  0.011363  0.562055  0.626182
# std    1.042933  0.920729  0.599299  1.035159
# min   -0.711432 -1.550923 -0.197505 -0.568167
# 25%   -0.249657 -0.397250  0.186733  0.026261
# 50%    0.558541  0.369524  0.584080  0.536997
# 75%    1.283399  0.619219  0.768444  0.863725
# max    1.931734  0.830442  1.517496  2.422611

# %%
Cardata = { "Mercedes": [2, 4, 0, 4, 0, 3], 
            "Ford": [3, 0, 0, 1, 6, 12], 
            "Tata":[9, 3, 4, 1, 0, 0], 
            "Renault":[12, 1, 0, 0, 3, 1]
          }

# %%
Carsales = pd.DataFrame(Cardata)

# %%
Carsales
# Out:
#    Mercedes  Ford  Tata  Renault
# 0         2     3     9       12
# 1         4     0     3        1
# 2         0     0     4        0
# 3         4     1     1        0
# 4         0     6     0        3
# 5         3    12     0        1

# %%
newsales = pd.DataFrame({"Mercedes":0, "Ford":1},index=[4])
Carsales = pd.concat([Carsales, newsales])

# %%
Carsales
# Out:
#    Mercedes  Ford  Tata  Renault
# 0         2     3   9.0     12.0
# 1         4     0   3.0      1.0
# 2         0     0   4.0      0.0
# 3         4     1   1.0      0.0
# 4         0     6   0.0      3.0
# 5         3    12   0.0      1.0
# 4         0     1   NaN      NaN

# %%
Carsales.loc[:,'Mercedes']
# Out:
# 0    2
# 1    4
# 2    0
# 3    4
# 4    0
# 5    3
# 4    0
# Name: Mercedes, dtype: int64

# %%
Jaguar = np.random.randint(1,10,7)
Carsales.insert(loc=4,column='Jaguar',value=Jaguar,allow_duplicates=False)

# %% [markdown]
# <h3>Dropping/ deleting columns</h3>

# %%
# Carsales.drop(columns=['Tesla'],inplace=True)

# %%
Carsales
# Out:
#    Mercedes  Ford  Tata  Jaguar  Renault
# 0         2     3   9.0       6     12.0
# 1         4     0   3.0       7      1.0
# 2         0     0   4.0       2      0.0
# 3         4     1   1.0       4      0.0
# 4         0     6   0.0       3      3.0
# 5         3    12   0.0       5      1.0
# 4         0     1   NaN       4      NaN

# %%
Mazda = np.random.random(7)
Tata = np.linspace(1,100,7,5)
new_sales = list(zip(Mazda,Tata))

# %%
Carsales2 = pd.DataFrame(new_sales, columns=['Mazda','Tata'])

# %%
Carsales2
# Out:
#       Mazda   Tata
# 0  0.410944    1.0
# 1  0.726588   17.5
# 2  0.158370   34.0
# 3  0.922379   50.5
# 4  0.293780   67.0
# 5  0.818009   83.5
# 6  0.542810  100.0

# %%
Carsales3 = pd.concat([Carsales,Carsales2],ignore_index=True)

# %%
Carsales3
# Out:
#     Mercedes  Ford   Tata  Jaguar  Renault     Mazda
# 0        2.0   3.0    9.0     6.0     12.0       NaN
# 1        4.0   0.0    3.0     7.0      1.0       NaN
# 2        0.0   0.0    4.0     2.0      0.0       NaN
# 3        4.0   1.0    1.0     4.0      0.0       NaN
# 4        0.0   6.0    0.0     3.0      3.0       NaN
# 5        3.0  12.0    0.0     5.0      1.0       NaN
# 6        0.0   1.0    NaN     4.0      NaN       NaN
# 7        NaN   NaN    1.0     NaN      NaN  0.410944
# 8        NaN   NaN   17.5     NaN      NaN  0.726588
# 9        NaN   NaN   34.0     NaN      NaN  0.158370
# 10       NaN   NaN   50.5     NaN      NaN  0.922379
# 11       NaN   NaN   67.0     NaN      NaN  0.293780
# 12       NaN   NaN   83.5     NaN      NaN  0.818009
# 13       NaN   NaN  100.0     NaN      NaN  0.542810
# 14       NaN   NaN    1.0     NaN      NaN  0.410944
# 15       NaN   NaN   17.5     NaN      NaN  0.726588
# 16       NaN   NaN   34.0     NaN      NaN  0.158370
# 17       NaN   NaN   50.5     NaN      NaN  0.922379
# 18       NaN   NaN   67.0     NaN      NaN  0.293780
# 19       NaN   NaN   83.5     NaN      NaN  0.818009
# 20       NaN   NaN  100.0     NaN      NaN  0.542810

# %%
Carsales3.to_csv('Carsales.csv')
Carsales3.to_excel('Carsales.xlsx')

# %% [markdown]
# ## Deleting Dataframe

# %%
del(Carsales)

# %% [markdown]
# ### Delete a row based on an index

# %%
Carsales3.drop([20])
# Out:
#     Mercedes  Ford   Tata  Jaguar  Renault     Mazda
# 0        2.0   3.0    9.0     6.0     12.0       NaN
# 1        4.0   0.0    3.0     7.0      1.0       NaN
# 2        0.0   0.0    4.0     2.0      0.0       NaN
# 3        4.0   1.0    1.0     4.0      0.0       NaN
# 4        0.0   6.0    0.0     3.0      3.0       NaN
# 5        3.0  12.0    0.0     5.0      1.0       NaN
# 6        0.0   1.0    NaN     4.0      NaN       NaN
# 7        NaN   NaN    1.0     NaN      NaN  0.410944
# 8        NaN   NaN   17.5     NaN      NaN  0.726588
# 9        NaN   NaN   34.0     NaN      NaN  0.158370
# 10       NaN   NaN   50.5     NaN      NaN  0.922379
# 11       NaN   NaN   67.0     NaN      NaN  0.293780
# 12       NaN   NaN   83.5     NaN      NaN  0.818009
# 13       NaN   NaN  100.0     NaN      NaN  0.542810
# 14       NaN   NaN    1.0     NaN      NaN  0.410944
# 15       NaN   NaN   17.5     NaN      NaN  0.726588
# 16       NaN   NaN   34.0     NaN      NaN  0.158370
# 17       NaN   NaN   50.5     NaN      NaN  0.922379
# 18       NaN   NaN   67.0     NaN      NaN  0.293780
# 19       NaN   NaN   83.5     NaN      NaN  0.818009
